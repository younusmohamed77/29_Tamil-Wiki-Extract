# %% [markdown]
# Final code along with check

# %%
import bz2
import os
import re
import time

# Regular expression pattern for XML tag extraction, with raw string to avoid escape sequence issues
tagRE = re.compile(r'(.*?)<(/?\w+)[^>]*>(?:([^<]*)(<.*?>)?)?')

# %%
class NextFile:
    """
    Class to manage the creation of sequential files for output.
    """
    filesPerDir = 100  # Max files per directory

    def __init__(self, path_name):
        self.path_name = path_name
        self.dir_index = -1
        self.file_index = -1

    def next(self):
        # Move to next file; create directory if needed
        self.file_index = (self.file_index + 1) % NextFile.filesPerDir
        if self.file_index == 0:
            self.dir_index += 1
        dirname = self._dirname()
        os.makedirs(dirname, exist_ok=True)
        return self._filepath()

    def _dirname(self):
        # Generate subdirectory name based on current indices
        char1 = self.dir_index % 26
        char2 = (self.dir_index // 26) % 26
        return os.path.join(self.path_name, f'{chr(ord("A") + char2)}{chr(ord("A") + char1)}')

    def _filepath(self):
        # Generate filepath for the next output file
        return f'{self._dirname()}/wiki_{self.file_index:02d}'


class OutputSplitter:
    """
    Class to manage output files, ensuring each file does not exceed a given size.
    """
    def __init__(self, nextFile, max_file_size=0, compress=True):
        self.nextFile = nextFile
        self.compress = compress
        self.max_file_size = max_file_size
        self.file = self.open(self.nextFile.next())

    def reserve(self, size):
        # Close and open a new file if current file exceeds max size
        if self.file.tell() + size > self.max_file_size:
            self.close()
            self.file = self.open(self.nextFile.next())

    def write_article(self, article_id, title, text):
        # Wrap each article with <doc> tags and write to file
        doc = f'<doc id="{article_id}" title="{title}">\n{text}\n</doc>\n\n'
        self.write(doc)

    def write(self, data):
        self.reserve(len(data))
        # Write data with compression if enabled
        self.file.write(data.encode('utf-8') if self.compress else data)

    def close(self):
        self.file.close()

    def open(self, filename):
        # Open file with or without compression
        return bz2.open(filename + '.bz2', 'wb') if self.compress else open(filename, 'w', encoding='utf-8')

# %%
def process_pages(input_file, output_directory, max_file_size=100 * 1024, compress=True):
    """
    Processes pages in the input XML file and outputs each article with <doc> tags.
    """
    next_file = NextFile(output_directory)
    output = OutputSplitter(next_file, max_file_size, compress)

    article_count = 0
    start_time = time.time()
    last_milestone = 0  # Tracks the last milestone printed

    with open(input_file, 'r', encoding='utf-8') as file:
        page = []
        title = ""
        for line in file:
            if '<' not in line:
                if page:
                    page.append(line)
                continue

            m = tagRE.search(line)
            if not m:
                continue
            tag = m.group(2)
            if tag == 'page':
                page = []
                title = ""
            elif tag == 'title':
                title = m.group(3) or ""
            elif tag == 'text':
                line = line[m.start(3):m.end(3)]
                page.append(line)
                if m.lastindex == 4:
                    output.write_article(article_count, title, " ".join(page))
                    page = []
                    article_count += 1
            elif tag == '/text' and page:
                output.write_article(article_count, title, " ".join(page))
                page = []
                article_count += 1
            elif tag == '/page':
                output.write_article(article_count, title, " ".join(page))
                page = []
                article_count += 1

            # Log progress every 100,000 articles
            if article_count >= last_milestone + 100000:
                elapsed_time = time.time() - start_time
                print(f"Processed {article_count} articles in {elapsed_time:.2f} seconds")
                last_milestone = article_count

    # Final log for total articles processed
    elapsed_time = time.time() - start_time
    print(f"Completed processing {article_count} articles in {elapsed_time:.2f} seconds")
    output.close()

# %%
def extract_bz2_to_txt(input_directory, output_directory):
    """
    Extracts all .bz2 files in input_directory to .txt files in output_directory.
    """
    # Ensure the output directory exists
    os.makedirs(output_directory, exist_ok=True)

    # Walk through all subdirectories and extract .bz2 files
    for subdir, _, files in os.walk(input_directory):
        for file in files:
            if file.endswith('.bz2'):
                bz2_file_path = os.path.join(subdir, file)

                # Maintain subdirectory structure in output directory
                relative_path = os.path.relpath(subdir, input_directory)
                output_subdir = os.path.join(output_directory, relative_path)
                os.makedirs(output_subdir, exist_ok=True)

                txt_file_path = os.path.join(output_subdir, file.replace('.bz2', '.txt'))

                # Extract content
                with bz2.open(bz2_file_path, 'rt', encoding='utf-8') as bz2_file:
                    with open(txt_file_path, 'w', encoding='utf-8') as txt_file:
                        txt_file.write(bz2_file.read())

                print(f"Extracted {bz2_file_path} to {txt_file_path}")

# %%
# Paths for input and output directories
input_file = r"C:\Users\Hi\My Works\My Py Scripts\Git Repos\29_Tamil Wiki\tawiki-20241101-pages-articles-multistream.xml"
output_directory = r"C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles"
input_directory = "C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles"
output_directory_txt = "C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles"

# %%
# Run the page processing and extraction functions
process_pages(input_file, output_directory, max_file_size=10 * 1024 * 1024, compress=True)
extract_bz2_to_txt(input_directory, output_directory_txt)
# Out:
# Processed 100000 articles in 17.87 seconds
# Processed 200000 articles in 28.06 seconds
# Processed 300000 articles in 43.39 seconds
# Processed 400000 articles in 58.05 seconds
# Processed 500000 articles in 76.21 seconds
# Completed processing 569055 articles in 88.00 seconds
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_00.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_00.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_01.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_01.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_02.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_02.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_03.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_03.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_04.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_04.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_05.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_05.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_06.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_06.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_07.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_07.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_08.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_08.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_09.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_09.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_10.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_10.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_11.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_11.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_12.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_12.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_13.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_13.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_14.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_14.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_15.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_15.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_16.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_16.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_17.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_17.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_18.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_18.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_19.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_19.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_20.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_20.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_21.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_21.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_22.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_22.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_23.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_23.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_24.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_24.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_25.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_25.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_26.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_26.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_27.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_27.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_28.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_28.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_29.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_29.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_30.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_30.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_31.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_31.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_32.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_32.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_33.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_33.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_34.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_34.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_35.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_35.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_36.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_36.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_37.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_37.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_38.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_38.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_39.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_39.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_40.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_40.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_41.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_41.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_42.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_42.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_43.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_43.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_44.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_44.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_45.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_45.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_46.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_46.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_47.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_47.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_48.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_48.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_49.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_49.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_50.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_50.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_51.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_51.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_52.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_52.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_53.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_53.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_54.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_54.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_55.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_55.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_56.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_56.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_57.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_57.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_58.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_58.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_59.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_59.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_60.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_60.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_61.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_61.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_62.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_62.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_63.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_63.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_64.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_64.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_65.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_65.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_66.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_66.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_67.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_67.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_68.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_68.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_69.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_69.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_70.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_70.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_71.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_71.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_72.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_72.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_73.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_73.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_74.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_74.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_75.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_75.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_76.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_76.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_77.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_77.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_78.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_78.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_79.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_79.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_80.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_80.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_81.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_81.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_82.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_82.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_83.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_83.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_84.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_84.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_85.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_85.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_86.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_86.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_87.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_87.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_88.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_88.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_89.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_89.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_90.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_90.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_91.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_91.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_92.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_92.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_93.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_93.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_94.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_94.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_95.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_95.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_96.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_96.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_97.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_97.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_98.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_98.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AA\wiki_99.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AA\wiki_99.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_00.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_00.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_01.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_01.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_02.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_02.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_03.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_03.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_04.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_04.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_05.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_05.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_06.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_06.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_07.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_07.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_08.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_08.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_09.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_09.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_10.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_10.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_11.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_11.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_12.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_12.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_13.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_13.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_14.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_14.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_15.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_15.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_16.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_16.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_17.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_17.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_18.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_18.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_19.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_19.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_20.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_20.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_21.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_21.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_22.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_22.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_23.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_23.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_24.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_24.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_25.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_25.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_26.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_26.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_27.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_27.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_28.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_28.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_29.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_29.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_30.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_30.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_31.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_31.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_32.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_32.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_33.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_33.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_34.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_34.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_35.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_35.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_36.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_36.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_37.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_37.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_38.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_38.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_39.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_39.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_40.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_40.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_41.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_41.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_42.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_42.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_43.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_43.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_44.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_44.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_45.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_45.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_46.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_46.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_47.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_47.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_48.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_48.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_49.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_49.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_50.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_50.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_51.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_51.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_52.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_52.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_53.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_53.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_54.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_54.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_55.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_55.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_56.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_56.txt
# Extracted C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/extracted_articles\AB\wiki_57.bz2 to C:/Users/Hi/My Works/My Py Scripts/Git Repos/29_Tamil Wiki/txt_articles\AB\wiki_57.txt

# %%
def count_articles_in_directory(directory):
    # Regex pattern to match <doc> tags
    doc_tag_pattern = re.compile(r'<doc id="[^"]*" title="[^"]*">')
    
    total_articles = 0  # Initialize article counter
    
    # Walk through all subdirectories and files in the specified directory
    for subdir, _, files in os.walk(directory):
        for file in files:
            if file.endswith('.txt'):
                file_path = os.path.join(subdir, file)
                
                # Open each text file and count <doc> tags
                with open(file_path, 'r', encoding='utf-8') as f:
                    content = f.read()
                    total_articles += len(doc_tag_pattern.findall(content))
    
    print(f"Total articles found: {total_articles}")

# %%
# Run the article count function
count_articles_in_directory(output_directory_txt)
# Out:
# Total articles found: 569055
